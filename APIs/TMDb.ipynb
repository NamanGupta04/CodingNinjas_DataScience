# %%
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":true,"status_code":1,"status_message":"Success."}

# %%
import requests

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}
data = requests.get("https://api.themoviedb.org/3/discover/movie" , headers = headers)
python_data = data.json()
#print(python_data)
#print(len(python_data))
for i in python_data['results']:
    print(i['title'])
# Out:
# The Creator
# Oppenheimer
# Five Nights at Freddy's
# Expend4bles
# Mission: Impossible - Dead Reckoning Part One
# Fast X
# The Hunger Games: The Ballad of Songbirds & Snakes
# Saw X
# The Equalizer 3
# Megalomaniac
# Pet Sematary: Bloodlines
# Blue Beetle
# Meg 2: The Trench
# The Nun II
# The Marvels
# Gran Turismo
# Sound of Freedom
# Trolls Band Together
# Retribution
# Transformers: Rise of the Beasts

# %%
import requests
params = {
        'api_key': 'cbee6b91444ab08a42741abad1093b71',
        'query': 'Andhadun',
    }
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}
data = requests.get("https://api.themoviedb.org/3/search/movie" , headers = headers , params = params)
python_data = data.json()
if 'results' in python_data and python_data['results']:
        # Assuming the first result is the most relevant
    print(python_data['results'][0]['id'])

# %%
import requests

def get_movie_id(api_token, movie_title):
    base_url = "https://api.themoviedb.org/3/search/movie"
    headers = {
        'Authorization': f'Bearer {api_token}',
    }
    params = {
        'query': movie_title,
    }
    response = requests.get(base_url, headers=headers, params=params)
    data = response.json()

    if 'results' in data and data['results']:
        return data['results'][0]['id']
    else:
        return None
api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs'
movie_title = 'Andhadhun'  

movie_id = get_movie_id(api_token, movie_title)

if movie_id:
    print(f"{movie_id}")
# Out:
# 534780

# %%
import requests

url = "https://api.themoviedb.org/3/search/company?page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}

params = {
        'query': 'Marvel Studios',
    }

response = requests.get(url, headers=headers , params = params)

data = response.json()
print("ID :",data['results'][0]['id'])
# Out:
# ID : 420

# %%
import requests

def get_movie_id(api_token, movie_title):
    base_url = "https://api.themoviedb.org/3/search/movie"
    headers = {
        'Authorization': f'Bearer {api_token}',
    }
    params = {
        'query': movie_title,
    }
    response = requests.get(base_url, headers=headers, params=params)
    data = response.json()

    if 'results' in data and data['results']:
        return data['results'][0]['id']
    else:
        return None

api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs'
movie_title = '3 Idiots'  

movie_id = get_movie_id(api_token, movie_title)

# if movie_id:
#     print(f"{movie_id}")
    
movie_id = 20453  # The TMDB ID for 3 Idiots

headers = {'Authorization': f'Bearer {api_token}'}

url = f'https://api.themoviedb.org/3/movie/{movie_id}?language=en-US'
response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    vote_count = data['vote_count']
    vote_average = data['vote_average']

    print(f"Vote Count: {vote_count}")
    print(f"Vote Average: {vote_average}")
# Out:
# Vote Count: 2183
# Vote Average: 8.0

# %%
import requests
## Write your code here
import json
header = {"Accept" : "application/json"}
r = requests.get("https://api.themoviedb.org/3/search/movie", params = 
                 {"query" : "Inception", "api_key" : "cbee6b91444ab08a42741abad1093b71"}, 
                 headers = header).json()
for i in r["results"]:
    if i["title"] == "Inception":
        id = i["id"]
similar_movies = requests.get(f"https://api.themoviedb.org/3/movie/{id}/similar", params = 
                              {"api_key" : "cbee6b91444ab08a42741abad1093b71"}, 
                              headers = header).json()
# print(similar_movies.status_code)
# print(similar_movies.url)
for i in similar_movies["results"][:5]:
    print(i["title"])
# Out:
# Sleep Dealer
# Kim Possible: So the Drama
# The Master
# Commitment
# Catch That Kid

# %%
import requests

def get_movie_id(api_token, movie_title):
    base_url = "https://api.themoviedb.org/3/search/movie"
    headers = {
        'Authorization': f'Bearer {api_token}',
    }
    params = {
        'query': movie_title,
    }
    response = requests.get(base_url, headers=headers, params=params)
    data = response.json()

    if 'results' in data and data['results']:
        return data['results'][0]['id']
    else:
        return None

api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs'
movie_title = 'Inception'  

movie_id = get_movie_id(api_token, movie_title)

if movie_id:
    print(f"{movie_id}")
# Out:
# 27205

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en&page=1&region=US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}

import requests

url2 = "https://api.themoviedb.org/3/genre/movie/list?language=en"


response = requests.get(url2, headers=headers).json()
genres = response['genres']
genres_dict = {genre['id']:genre['name'] for genre in genres}

r = requests.get(url, headers=headers).json()
movie_list = r['results']
count = 0
for i in r['results']:
    if i['original_language'] == 'en':
        genre_name = [genres_dict[j] for j in i['genre_ids']]
        print(i['original_title'],"-",",".join(genre_name))
        count+=1
    if count==10:
        break
# Out:
# The Godfather - Drama,Crime
# The Shawshank Redemption - Drama,Crime
# The Godfather Part II - Drama,Crime
# Schindler's List - Drama,History,War
# 12 Angry Men - Drama
# The Dark Knight - Drama,Action,Crime,Thriller
# The Green Mile - Fantasy,Drama,Crime
# Pulp Fiction - Thriller,Crime
# Forrest Gump - Comedy,Drama,Romance
# The Lord of the Rings: The Return of the King - Adventure,Fantasy,Action

# %%
import requests

url = "https://api.themoviedb.org/3/person/popular"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}

response = requests.get(url, headers=headers).json()
prsn = response['results']
print(prsn[0]['id'])
# Out:
# 4068148

# %%
import requests
## Write your code here

apiKey = 'ffafe1f2b141d9a9fcae15771fe46db1'

res = requests.get('https://api.themoviedb.org/3/person/popular',params={'api_key':apiKey}) 
data=res.json()
data=data['results'][0]

MostPopularId=data['id']

print(MostPopularId)
res = requests.get('https://api.themoviedb.org/3/person/4068148',params={'api_key':apiKey}) 
data=res.json()
print(data['name'],'-',data['place_of_birth'])
# Out:
# 4068148
# Madeleine Yuna Voyles - San Diego, California, USA

# %%
import requests
param={'query':'alia bhatt'}
url = "https://api.themoviedb.org/3/search/person"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}

response = requests.get(url,params = param ,headers=headers).json()
prsnid = response['results'][0]['id']
#print(prsnid)

res = requests.get("https://api.themoviedb.org/3/person/1108120/external_ids",headers = headers) 
data=res.json()
print(data['instagram_id']," ",data['twitter_id'])
# Out:
# 1108120
# aliaabhatt   Aliaa08

# %%
import requests

api_key = 'cbee6b91444ab08a42741abad1093b71'
base_url = 'https://api.themoviedb.org/3'

movie_titles = ['Top Gun', 'Mission: Impossible - Fallout', 'Minority Report', 'Edge of Tomorrow']

def get_actor_id(actor_name):
    search_url = f'{base_url}/search/person'
    params = {'api_key': api_key, 'query': actor_name}
    response = requests.get(search_url, params=params).json()
    actor_id = response['results'][0]['id'] if response['results'] else None
    return actor_id

# Function to get the characters played by an actor in a movie
def get_characters(actor_id, movie_title):
    credits_url = f'{base_url}/person/{actor_id}/movie_credits'
    params = {'api_key': api_key}
    response = requests.get(credits_url, params=params).json()
    
    for credit in response.get('cast', []):
        if credit['title'] == movie_title:
            return credit.get('character')
    
    return None

tom_cruise_id = get_actor_id('Tom Cruise')

if tom_cruise_id:
    for movie_title in movie_titles:
        character = get_characters(tom_cruise_id, movie_title)
        if character:
            print(character)
else:
    print("Tom Cruise not found.")
# Out:
# Lt. Pete 'Maverick' Mitchell
# Ethan Hunt
# Chief John Anderton [Pre-Crime]
# Maj. William 'Bill' Cage

# %%
import requests
param={'query':'deadpool 2'}
url = "https://api.themoviedb.org/3/search/movie"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}

response = requests.get(url,params = param ,headers=headers).json()
movie_id=response['results'][0]['id']
#print(movie_id)

r = requests.get("https://api.themoviedb.org/3/movie/383498/credits",headers = headers).json()
name = "James McAvay"
cast = r['cast']
for name in cast:
    if name:
        print('Yes')
        break
    else:
        print('No')
# Out:
# Yes

# %%
import requests
param={'query':'deadpool 2'}
url = "https://api.themoviedb.org/3/search/movie"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}

response = requests.get(url,params = param ,headers=headers).json()
movie_id=response['results'][0]['id']
#print(movie_id)

r = requests.get("https://api.themoviedb.org/3/movie/383498/credits",headers = headers).json()
Name = "James McAvay"
cast = r['cast']
for i in cast:
    if (i['name']==Name and i['credit_id']==True):
        print("Yes")
    else:
        print("No")
        break
# Out:
# No

# %%
import requests
param={'query':'FRIENDS'}
url = "https://api.themoviedb.org/3/search/tv"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}
response = requests.get(url,params = param ,headers=headers).json()
print(response['results'][0]['overview'])
# Out:
# Six young people from New York City, on their own and struggling to survive in the real world, find the companionship, comfort and support they get from each other to be the perfect antidote to the pressures of life.

# %%
import requests
param={'query':'The Big Bang Theory'}
url = "https://api.themoviedb.org/3/search/tv"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}
response = requests.get(url,params = param ,headers=headers).json()
series_id = response['results'][0]['id']



url2="https://api.themoviedb.org/3/tv/1418/season/06/episode/05"
res = requests.get(url2,params = param ,headers=headers).json()
print(res['name'],"-",res['air_date'])
# Out:
# The Holographic Excitation - 2012-10-25

# %%
import requests

url = "https://api.themoviedb.org/3/trending/tv/week?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}

response = requests.get(url, headers=headers).json()

trending_id=[]

for i in response['results'][:5]:
    trending_id.append(i['id'])
    
#[1429, 84958, 202411, 37854, 155292] 


def taglines(ids):
    headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}
    for series_id in ids: 
        #print(series_id)
        url = f'https://api.themoviedb.org/3/tv/{series_id}'
        r = requests.get(url,headers=headers).json()
        if r['tagline']=='':
            print('Empty')
        else:
            print(r['tagline'])
taglines(trending_id)
# Out:
# Empty
# Loki's time has come.
# Some secrets cannot be contained.
# Set sail for One Piece!
# Empty

# %%
from datetime import datetime 
import requests

url = 'https://api.themoviedb.org/3/tv/airing_today'
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYmVlNmI5MTQ0NGFiMDhhNDI3NDFhYmFkMTA5M2I3MSIsInN1YiI6IjY1NTZmMTU4N2YwNTQwMDEzOWVjYmJmZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DmU-r0nxmUyp-y1DcSTDkfNgjwhMJkIC_H4hcz1pLTs"
}
params={}
response = requests.get(url,headers=headers).json()
for i in range(1,response['total_pages']+1):
    params['page'] = i
    response = requests.get(url, params=params,headers=headers).json()
    for i in response['results']:
        if i['original_language'] == 'en':
            print(i['name'])
# Out:
# The Price Is Right
# The Daily Show
# The Late Show with Stephen Colbert
# Survivor
# Let's Make a Deal
# Richard Osman's House of Games
# Emmerdale
# Hollyoaks
# EastEnders
# PBS NewsHour
# Survivor
# The Lazarus Project
# Late Night with Seth Meyers
# Pointless
# Coronation Street
# Big Brother
# Days of Our Lives
# Naked News
# CBS Evening News
# The View
# Home and Away
# Shortland Street
# The Buccaneers
# The Kelly Clarkson Show
# NOVA
# Shetland
# The Real Housewives of Beverly Hills
# All Elite Wrestling: Dynamite
# Doctors
# Squid Game: The Challenge
# Black Cake
# The Santa Clauses
# General Hospital
# Doctors
# General Hospital
# MasterChef: The Professionals
# Chopped
# Beat Bobby Flay
# Ink Master
# SpongeBob SquarePants
# Escape to the Country
# A League of Their Own
# Love Island Australia
# Secrets of the Dead
# Life Below Zero
# SurrealEstate
# Split Second
# Neighbours
# I'm a Celebrity...Get Me Out of Here!
# High on the Hog: How African American Cuisine Transformed America
# Court Cam
# Children Ruin Everything
# The Real Housewives of Miami
# The Jennifer Hudson Show
# High on the Hog: How African American Cuisine Transformed America
# Kurzgesagt - In a Nutshell
# I'm a Celebrity...Get Me Out of Here!
# Dad's Army: The Animations
# The Bermuda Triangle: Into Cursed Waters
# Winter House
# Teen First Dates
# Trails to Oishii Tokyo
# Dateline: Unforgettable
# Fixer Upper: The Hotel
# The ReidOut
# Artfully Designed
# Shorty's Dream Shop
# The Secret Genius of Modern Life
# Love It or List It Australia
# The Secret Genius of Modern Life
# Love It or List It Australia
# Australian Epic
# Shakespeare: Rise of a Genius
# Interrogation Cam
# Roadworthy Rescues
# Magical Japanese
# Luke Nguyen's India
# Feds
# Aerial Adventures
# Crimefeed
# a bear cloud
# Help! We Bought A Village
# Oluja
# Power Slap: Road to the Title
# iCrime with Elizabeth Vargas
# iCrime with Elizabeth Vargas
# Mathis Court With Judge Mathis
# Switch
# Hit the Road
# Such Brave Girls
# Vanished: The Hunt For Britain's Missing People
# Cause of Death
# Live from Daryl's House
# Kin
# Sunken Warships: Secrets from the Deep
# Slum Golf
# Deal Or No Deal (UK) (2023)

# %%
import requests 
api_key = "cbee6b91444ab08a42741abad1093b71" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"Money Heist" , 'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/search/tv/", headers = header, params = params) 
data = response.json() 
print(data)
for result in results: 
    if result.get('name') == 'Money Heist': 
        id = result.get('id') 
params2 ={"id":id,'api_key':api_key} 
response2 =requests.get(api_link + "/tv/" + str(id) + "/credits", headers = header, params = params2) 
data2 = response2.json() 
cast = data2.get("cast") 
count_male = 0 
count_female = 0 
for c in cast: 
    if c.get("gender") == 1: 
        count_female += 1 
    if c.get("gender") == 2: 
        count_male += 1 
print(count_male,count_female)
# Out:
# {'success': False, 'status_code': 34, 'status_message': 'The resource you requested could not be found.'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24800\2046275234.py in <module>
#       7 data = response.json()
#       8 print(data)
# ----> 9 for result in results:
#      10     if result.get('name') == 'Money Heist':
#      11         id = result.get('id')
#
# TypeError: 'NoneType' object is not iterable

# %%
import requests

# Replace 'YOUR_API_KEY' with your actual TMDB API key
api_key = 'cbee6b91444ab08a42741abad1093b71'
base_url = 'https://api.themoviedb.org/3'

# Function to get TV series ID by name
def get_tv_series_id(series_name):
    search_url = f'{base_url}/search/tv'
    params = {'api_key': api_key, 'query': series_name}
    response = requests.get(search_url, params=params).json()
    tv_series_id = response['results'][0]['id'] if response['results'] else None
    return tv_series_id

# Function to get the cast of a TV series
def get_tv_series_cast(tv_series_id):
    cast_url = f'{base_url}/tv/{tv_series_id}/credits'
    params = {'api_key': api_key}
    response = requests.get(cast_url, params=params).json()
    return response.get('cast', [])

# Function to estimate gender based on names using the Genderize API
def estimate_gender(name):
    genderize_url = f'https://api.genderize.io?name={name}'
    response = requests.get(genderize_url).json()
    return response.get('gender')

# TV series details
series_name = 'Money Heist'

# Get TV series ID
tv_series_id = get_tv_series_id(series_name)

if tv_series_id:
    # Get the cast of the TV series
    cast = get_tv_series_cast(tv_series_id)

    # Count the number of males and females based on estimated gender
    males = females = 0

    for actor in cast:
        name = actor['name'].split()[0]  # Use only the first name for simplicity
        estimated_gender = estimate_gender(name)

        if estimated_gender == 'male':
            males += 1
        elif estimated_gender == 'female':
            females += 1

    print(f"Number of Males: {males}")
    print(f"Number of Females: {females}")

else:
    print(f"TV series '{series_name}' not found.")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24800\2786233234.py in <module>
#      41     for actor in cast:
#      42         name = actor['name'].split()[0]  # Use only the first name for simplicity
# ---> 43         estimated_gender = estimate_gender(name)
#      44
#      45         if estimated_gender == 'male':
#
# ~\AppData\Local\Temp\ipykernel_24800\2786233234.py in estimate_gender(name)
#      23 def estimate_gender(name):
#      24     genderize_url = f'https://api.genderize.io?name={name}'
# ---> 25     response = requests.get(genderize_url).json()
#      26     return response.get('gender')
#      27
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     973             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#     977     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
