# %%
import numpy as np

# %%
data = np.loadtxt("data.csv", delimiter=",")

# %%
x = data[:, 0].reshape(-1, 1) #  hence we reshape 1d array to 2d array 
y = data[:, 1]

# %%
x.shape
# Out:
# (100, 1)

# %%
from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(x, y)

# %%
from sklearn.linear_model import LinearRegression
alg1 = LinearRegression()
alg1.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
alg1.coef_ # y = m*x + c .......coef_= m   we cant direct fit the data ..coz it is 1d array ..and it requires 2d array
# Out:
# array([1.36313138])

# %%
alg1.intercept_
# Out:
# 5.870512799042615

# %%
import matplotlib.pyplot as plt
m = alg1.coef_[0]
c = alg1.intercept_

x_line = np.arange(30,70,0.1)
y_line = m * x_line + c
plt.plot(x_line, y_line, "r")
train_1d = X_train.reshape(75)
plt.scatter(X_train, Y_train)
plt.show()

# %%
import matplotlib.pyplot as plt
m = alg1.coef_[0]
c = alg1.intercept_

x_line = np.arange(30,70,0.1)
y_line = m * x_line + c
plt.plot(x_line, y_line, "r")
train_1d = X_test.reshape(25)
plt.scatter(X_test, Y_test)
plt.show()

# %%
data = np.loadtxt('FuelEconomy.csv',delimiter = ',')

x = data[:,0].reshape(-1,1)
y = data[:,1]

from sklearn import model_selection
x_train ,x_test ,y_train , y_test = model_selection.train_test_split(x,y,random_state = 42 , test_size = 0.3)

# %%
from sklearn.linear_model import LinearRegression

alg2 = LinearRegression()
alg2.fit(x_train , y_train)

coeff = alg2.coef_[0]
intercept = alg2.intercept_
# Out:
# LinearRegression()

# %%
print(format(alg2.coef_[0],".2f"))
print(format(alg2.intercept_,".2f"))
# Out:
# -0.07
# 38.84
